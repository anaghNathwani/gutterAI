# %% [markdown]
# <a href="https://colab.research.google.com/github/anaghNathwani/gutterAI/blob/main/ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3D Model AI with Chat Capabilities
#
# This notebook outlines an AI model with chat capabilities that can primarily generate 3D models. It uses the Gemini API as a placeholder for current integration.

# %%
import google.generativeai as genai
from google.colab import userdata
import os

# Ensure the latest google-generativeai library is installed
# This is important as the API methods can change between versions.
# !pip install --upgrade google-generativeai

# Placeholder for Gemini API Key setup
# In a real scenario, you would retrieve your API key securely
# and configure genai.
# For now, we'll use a dummy placeholder.
try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    # Use configure for google.generativeai
    genai.configure(api_key=GOOGLE_API_KEY)
    print("Gemini API configured (using placeholder).")
except Exception:
    print("WARNING: Gemini API key not found in userdata. Using a dummy key.")
    # This is a placeholder for demonstration purposes.
    # DO NOT use a hardcoded key in production.
    # Use configure for google.generativeai
    genai.configure(api_key="YOUR_DUMMY_GEMINI_API_KEY")

# Placeholder for Gemini model initialization
# In a real scenario, you would specify the model, e.g., 'gemini-pro'
gemini_model = "placeholder_gemini_model" # Replace with actual model once integrated
print(f"Gemini model initialized as: {gemini_model}")
# Out:
# WARNING: Gemini API key not found in userdata. Using a dummy key.
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5719/1865725485.py in <cell line: 0>()
#       9 try:
# ---> 10     GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
#      11     # Use set_api_key for google.genai
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#
# SecretNotFoundError: Secret GOOGLE_API_KEY does not exist.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5719/1865725485.py in <cell line: 0>()
#      17     # DO NOT use a hardcoded key in production.
# ...

# %%
def chat_with_ai(prompt: str) -> str:
    """
    Placeholder function for chat interaction with the AI.
    In a real implementation, this would interact with a Gemini chat model.
    """
    print(f"Chat received: '{prompt}'")
    # Simulate a response from a chat AI
    if "hello" in prompt.lower():
        return "Hello there! How can I help you with 3D models today?"
    elif "3d model" in prompt.lower():
        return "I can help you generate 3D models. What kind of model are you thinking of?"
    else:
        return f"This is a placeholder chat response for: '{prompt}'"

# %%
def generate_3d_model(description: str) -> str:
    """
    Placeholder function for 3D model generation.
    In a real implementation, this would involve complex logic
    to interpret the description and generate or fetch a 3D model.
    This might involve another AI model or a specific API.
    """
    print(f"3D Model generation request received: '{description}'")
    # Simulate a response for 3D model generation
    return f"Generating a 3D model based on: '{description}'. (Placeholder for actual generation)"

# %%
# --- Main interaction loop (placeholder demo) ---
print("--- Starting AI 3D Model Chat Demo ---")

# Example chat interaction
chat_response = chat_with_ai("Hello, I want to create a 3D model.")
print(f"AI Chat: {chat_response}\n")

# Example 3D model generation
model_description = "a futuristic spaceship with sleek lines and glowing engines"
model_generation_response = generate_3d_model(model_description)
print(f"AI 3D Model Gen: {model_generation_response}\n")

print("--- Demo Finished ---")
# Out:
# --- Starting AI 3D Model Chat Demo ---
# Chat received: 'Hello, I want to create a 3D model.'
# AI Chat: Hello there! How can I help you with 3D models today?
#
# 3D Model generation request received: 'a futuristic spaceship with sleek lines and glowing engines'
# AI 3D Model Gen: Generating a 3D model based on: 'a futuristic spaceship with sleek lines and glowing engines'. (Placeholder for actual generation)
#
# --- Demo Finished ---

# %%
# %%writefile 3d_model_ai.py
import google.generativeai as genai
from google.colab import userdata
import os

# Placeholder for Gemini API Key setup
# In a real scenario, you would retrieve your API key securely
# and configure genai.
# For now, we'll use a dummy placeholder.
try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=GOOGLE_API_KEY)
    print("Gemini API configured (using placeholder).")
except Exception:
    print("WARNING: Gemini API key not found in userdata. Using a dummy key.")
    # This is a placeholder for demonstration purposes.
    # DO NOT use a hardcoded key in production.
    genai.configure(api_key="YOUR_DUMMY_GEMINI_API_KEY")

# Placeholder for Gemini model initialization
# In a real scenario, you would specify the model, e.g., 'gemini-pro'
gemini_model = "placeholder_gemini_model" # Replace with actual model once integrated
print(f"Gemini model initialized as: {gemini_model}")

def chat_with_ai(prompt: str) -> str:
    """
    Placeholder function for chat interaction with the AI.
    In a real implementation, this would interact with a Gemini chat model.
    """
    print(f"Chat received: '{prompt}'")
    # Simulate a response from a chat AI
    if "hello" in prompt.lower():
        return "Hello there! How can I help you with 3D models today?"
    elif "3d model" in prompt.lower():
        return "I can help you generate 3D models. What kind of model are you thinking of?"
    else:
        return f"This is a placeholder chat response for: '{prompt}'"

def generate_3d_model(description: str) -> str:
    """
    Placeholder function for 3D model generation.
    In a real implementation, this would involve complex logic
    to interpret the description and generate or fetch a 3D model.
    This might involve another AI model or a specific API.
    """
    print(f"3D Model generation request received: '{description}'")
    # Simulate a response for 3D model generation
    return f"Generating a 3D model based on: '{description}'. (Placeholder for actual generation)"

# --- Main interaction loop (placeholder demo) ---
if __name__ == "__main__":
    print("--- Starting AI 3D Model Chat Demo ---")

    # Example chat interaction
    chat_response = chat_with_ai("Hello, I want to create a 3D model.")
    print(f"AI Chat: {chat_response}\n")

    # Example 3D model generation
    model_description = "a futuristic spaceship with sleek lines and glowing engines"
    model_generation_response = generate_3d_model(model_description)
    print(f"AI 3D Model Gen: {model_generation_response}\n")

    print("--- Demo Finished ---")
# Out:
# Overwriting 3d_model_ai.py

# %% [markdown]
# ## Notebook Version
#
# This current notebook you are interacting with (`3d_model_ai.ipynb`) serves as the `.ipynb` version of the codebase. To save it, you can use the Colab menu: `File -> Save a copy in GitHub` or `File -> Save a copy in Drive`.

# %%
# Configure Git user identity
# IMPORTANT: Replace "your_email@example.com" and "Your Name" with your actual GitHub email and username.
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# Commands to push the new Python file to your GitHub repository.
# Please save this notebook manually (File -> Save a copy in GitHub)
# if you want to include the .ipynb version in the commit.
# !git add 3d_model_ai.py
# !git commit -m "feat: Initial commit for 3D Model AI with Chat capabilities (placeholders)"

# --- Pushing to GitHub ---
# For 'git push' to work in Colab, you often need to use a Personal Access Token (PAT).
# 1. Create a PAT on GitHub: Go to Settings -> Developer settings -> Personal access tokens -> Tokens (classic) -> Generate new token.
#    Give it a descriptive name and select the 'repo' scope. Copy the token.
# 2. When prompted for username/password during 'git push', use your GitHub username and paste the PAT as the password.
#    Alternatively, you can embed the PAT directly in the remote URL (replace <YOUR_PAT>, <YOUR_USERNAME>, <YOUR_REPO>):
#    !git remote set-url origin https://<YOUR_PAT>@github.com/<YOUR_USERNAME>/<YOUR_REPO>.git
#    Then run !git push
# !git push

print("\nAfter running these commands, remember to manually save this notebook (File -> Save a copy in GitHub) to ensure the .ipynb file is also pushed, and then you may need to run 'git add 3d_model_ai.ipynb', 'git commit', and 'git push' again if Colab doesn't handle it automatically.")
print("If 'git push' fails, it is likely due to authentication. You will need to use a Personal Access Token (PAT) for GitHub. See instructions above.")
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	db.sqlite3
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: could not read Username for 'https://github.com': No such device or address
#
# After running these commands, remember to manually save this notebook (File -> Save a copy in GitHub) to ensure the .ipynb file is also pushed, and then you may need to run 'git add 3d_model_ai.ipynb', 'git commit', and 'git push' again if Colab doesn't handle it automatically.
# If 'git push' fails, it is likely due to authentication. You will need to use a Personal Access Token (PAT) for GitHub. See instructions above.

# %%
import os
import pkg_resources

# Ensure chatterbot-corpus is installed
# !pip install chatterbot-corpus

# Dynamically find the actual installed path of the English corpus
try:
    actual_corpus_path = pkg_resources.resource_filename('chatterbot_corpus', 'data/english')
    print(f"ChatterBot English corpus found at: {actual_corpus_path}")

    # Define the path where ChatterBot is incorrectly looking
    expected_corpus_root = "/root/chatterbot_corpus/data"
    expected_corpus_path = os.path.join(expected_corpus_root, "english")

    # Create the target directory structure if it doesn't exist
    os.makedirs(expected_corpus_root, exist_ok=True)

    # Create a symbolic link if it doesn't exist or is invalid
    if not os.path.exists(expected_corpus_path) or not os.path.islink(expected_corpus_path):
        if os.path.exists(expected_corpus_path): # Remove if it's a file or directory, not a link
            if os.path.isdir(expected_corpus_path) and not os.path.islink(expected_corpus_path):
                # If it's a directory, remove its contents and then the directory itself.
                # This is a bit risky, but necessary if a non-symlink directory exists.
                # For now, let's assume if it exists and is not a link, it's safe to remove if empty or proceed carefully.
                import shutil
                shutil.rmtree(expected_corpus_path, ignore_errors=True)
            else:
                os.remove(expected_corpus_path)
        os.symlink(actual_corpus_path, expected_corpus_path)
        print(f"Created symlink from {actual_corpus_path} to {expected_corpus_path}")
    else:
        print(f"Symlink {expected_corpus_path} already exists or is valid.")

except Exception as e:
    print(f"Could not setup ChatterBot corpus symlink: {e}")

# Now run the main script
# !python3 main.py
# Out:
# /tmp/ipykernel_5719/66575514.py:2: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 7.0 MB/s eta 0:00:00
# ...
# ChatterBot English corpus found at: /usr/local/lib/python3.12/dist-packages/chatterbot_corpus/data/english
# Created symlink from /usr/local/lib/python3.12/dist-packages/chatterbot_corpus/data/english to /root/chatterbot_corpus/data/english
# Training corpus: 19it [00:03,  7.76it/s]
